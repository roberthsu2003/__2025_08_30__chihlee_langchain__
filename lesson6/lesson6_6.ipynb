# %%
# 導入必要的套件
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnableParallel, RunnableLambda
from langchain_ollama import ChatOllama

# 建立 Ollama 模型
model = ChatOllama(
    model="gpt-oss:20b",
    temperature=0.7
)

# %%
# 定義主要的提示模板 - 餐廳評論分析
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", "你是一個專業的餐廳評論家，擅長分析餐廳的優缺點。"),
        ("human", "請分析這家餐廳：{restaurant_info}"),
    ]
)

# %%
chain = (
    prompt_template
    | model
    | StrOutputParser()
)

# %%
restaurant_info = """
這是一家位於台北市中心的義大利餐廳，提供傳統義式料理。
餐廳環境優雅，服務人員親切，但價格偏高，等待時間較長。
食物品質不錯，但份量偏少。適合約會或特殊場合用餐。
"""

result = chain.invoke({"restaurant_info": restaurant_info})

print(result)
# Out:
# **餐廳概覽**
# - **地點**：台北市中心，交通便利，周邊商圈繁華。
# - **主題**：義大利傳統料理，注重地道風味。
# - **環境**：典雅的裝潢與柔和燈光，營造出舒適且有品味的用餐氛圍。
# - **服務**：服務人員態度親切、禮貌，對菜單熟悉，能提供適時的建議。
#
# ---
#
# ## 優點分析
#
# | 方面 | 具體表現 | 為何值得推薦 |
# |------|----------|--------------|
# | **環境** | 優雅的室內裝潢、柔和燈光、適度音樂 | 為約會、紀念日或商務聚餐提供高質感背景 |
# | **服務** | 服務人員親切、反應迅速、能解說菜品 | 讓客人感到被重視，提升整體體驗 |
# | **食物品質** | 料理口味符合義大利傳統，食材新鮮 | 口感純正，能滿足對正宗義式料理的期待 |
# | **適合場合** | 適合約會、特殊場合 | 環境與菜品相輔相成，能營造浪漫氛圍 |
#
# ---
#
# ## 缺點分析
#
# | 方面 | 具體表現 | 可能影響 |
# |------|----------|----------|
# | **價格** | 相較同區域其他義式餐廳偏高 | 可能讓預算有限的客人望而卻步 |
# | **等待時間** | 用餐高峰期需等待較長 | 影響用餐節奏，可能導致不便 |
# | **份量** | 份量較小 | 可能不適合胃口較大或想要多品嚐多道菜的客人 |
#
# ---
#
# ## 建議與改進方向
#
# 1. **價格定位**
#    - 可以考慮推出「午餐特惠」或「套餐優惠」，以吸引對價格敏感的客群。
#    - 或在菜單中加入「小份」或「分享盤」選項，降低單人消費門檻。
#
# 2. **等待時間管理**
#    - 透過預約系統減少現場等候，或在高峰時段提供「快速點餐」服務。
#    - 在等待區設置簡易小吃或飲料，提升客戶等待體驗。
#
# 3. **份量調整**
#    - 在菜單中明確標示份量大小，並提供「加份」或「雙份」選項。
#    - 針對想要嘗試多種菜色的客人，可推出「菜單試吃」套餐。
#
# 4. **宣傳重點**
#    - 強調「高品質、正宗義式」與「適合約會/特殊場合」的定位，並配合精美的菜品照片。
#    - 在社群媒體上分享客人用餐瞬間，營造情感共鳴。
#
# ---
#
# ## 總結
#
# 這家位於台北市中心的義大利餐廳，擁有優雅的用餐環境與親切的服務，能提供正宗且口感不錯的義式料理，特別適合約會或特殊場合。然而，價格偏高、等待時間較長以及份量偏少的問題，可能會限制部分客群的選擇。若能在價格策略、等候管理及份量設計上做適度調整，將更能提升整體競爭力，滿足更廣泛的消費者需求。
