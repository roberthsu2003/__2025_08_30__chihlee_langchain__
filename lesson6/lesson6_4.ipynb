# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain_ollama.llms import OllamaLLM

#model = OllamaLLM(model="llama3.2:latest")
model = OllamaLLM(model="gpt-oss:20b")

# %%
prompt_template = ChatPromptTemplate.from_messages([
    ("system","你是一個專業的客服代表，負責回覆客戶郵件。請用友善、專業的語調回覆。"),
    ("human","請回覆這封客戶郵件：\n\n{email_content}")
])

# %%
chain = (prompt_template 
        | model
        | StrOutputParser()
)

# %%
customer_email = """您好:

我最近購買了貴公司的產品，但是發現包裝有損壞，而且產品功能與說明書不符。
請問可以退貨或換貨嗎？我已經購買一週了。

期待您的回覆。


王小明"""

# %%
result = chain.invoke({
    "email_content":customer_email
})

print(result)
# Out:
# 尊敬的王小明先生／女士，
# 您好！
#
# 首先感謝您選擇我們的產品，並對此次購買經驗造成的不便與失望深表歉意。針對您所提及的包裝損壞及功能與說明書不符的問題，我們將盡快協助您解決。
#
# ### 1️⃣ 步驟說明
# 1. **拍攝照片**
#    - 請拍攝（1）完整產品包裝（包裝表面、外箱、密封條等）；
#    - （2）產品實際外觀；
#    - （3）功能異常的畫面或測試紀錄。
#    這將有助於我們快速判斷問題並為您辦理退換貨。
#
# 2. **回傳照片**
#    - 您可以將照片以附件形式回覆此郵件，或使用「附件」功能上傳。
#
# 3. **申請退換貨**
#    - 收到照片後，我們的客服團隊會於 48 小時內與您聯繫，提供退貨地址或安排換貨流程。
#    - 退貨時請使用原包裝（若仍完好）並保留所有附件（說明書、保證卡等）。
#    - 退貨費用將由我們承擔，並在商品確認無誤後全額退款或立即寄送換貨。
#
# ### 2️⃣ 退換貨政策
# - **退貨時限**：自您收到商品起 30 天內。
# - **退貨原因**：產品損壞、功能不符、與說明書不符等均屬可退換原因。
# - **退款方式**：退還至原支付方式，或如您需要，可轉為禮品卡等。
#
# ### 3️⃣ 如需進一步協助
# - 若您無法即時提供照片，請告知，我們可以先提供臨時退換貨憑證。
# - 若您需要協助聯繫物流或確認寄件方式，我們亦可提供。
#
# 再次感謝您的耐心與配合。若您有任何疑問，或想直接聯繫我們的客戶服務熱線（400‑XXXX‑XX），請隨時告知，我們將竭誠為您服務。
#
# 祝您生活愉快，期待為您儘速處理此事！
#
# 此致
# 敬禮
#
# **[公司名稱] 客戶服務團隊**
# 電話：400‑XXXX‑XX
# 電子信箱：service@[company].com
# 網站： www.[company].com
